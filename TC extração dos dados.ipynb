# %% [markdown]
# #Extração

# %% [markdown]
# Utilizamos comandos linux pra extrair os dados direto do site do IBGE: https://www.ibge.gov.br/estatisticas/investigacoes-experimentais/estatisticas-experimentais/27946-divulgacao-semanal-pnadcovid1?t=downloads&utm_source=covid19&utm_medium=hotsite&utm_campaign=covid_19.
# Após, copiamos os dados para o DBFS para uso em outro notebook.

# %%
# %sh
wget https://ftp.ibge.gov.br/Trabalho_e_Rendimento/Pesquisa_Nacional_por_Amostra_de_Domicilios_PNAD_COVID19/Microdados/Dados/PNAD_COVID_072020.zip &&
# Out:
# --2023-10-31 20:02:10--  https://ftp.ibge.gov.br/Trabalho_e_Rendimento/Pesquisa_Nacional_por_Amostra_de_Domicilios_PNAD_COVID19/Microdados/Dados/PNAD_COVID_072020.zip
# Resolving ftp.ibge.gov.br (ftp.ibge.gov.br)... 191.235.100.86
# Connecting to ftp.ibge.gov.br (ftp.ibge.gov.br)|191.235.100.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12383239 (12M) [application/zip]
# Saving to: ‘PNAD_COVID_072020.zip.2’
#
#      0K .......... .......... .......... .......... ..........  0%  129K 94s
#     50K .......... .......... .......... .......... ..........  0% 1.96M 50s
#    100K .......... .......... .......... .......... ..........  1%  257K 48s
#    150K .......... .......... .......... .......... ..........  1%  295K 46s
#    200K .......... .......... .......... .......... ..........  2% 1.94M 38s
#    250K .......... .......... .......... .......... ..........  2%  298K 38s
# ...

# %%
# %sh
unzip PNAD_COVID_072020.zip.2
# Out:
# Archive:  PNAD_COVID_072020.zip.2
#   inflating: PNAD_COVID_072020.csv

# %%
# %sh
wget https://ftp.ibge.gov.br/Trabalho_e_Rendimento/Pesquisa_Nacional_por_Amostra_de_Domicilios_PNAD_COVID19/Microdados/Dados/PNAD_COVID_082020.zip
# Out:
# --2023-10-31 20:04:48--  https://ftp.ibge.gov.br/Trabalho_e_Rendimento/Pesquisa_Nacional_por_Amostra_de_Domicilios_PNAD_COVID19/Microdados/Dados/PNAD_COVID_082020.zip
# Resolving ftp.ibge.gov.br (ftp.ibge.gov.br)... 191.235.100.86
# Connecting to ftp.ibge.gov.br (ftp.ibge.gov.br)|191.235.100.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12388172 (12M) [application/zip]
# Saving to: ‘PNAD_COVID_082020.zip’
#
#      0K .......... .......... .......... .......... ..........  0%  127K 95s
#     50K .......... .......... .......... .......... ..........  0% 25.5M 48s
#    100K .......... .......... .......... .......... ..........  1%  128K 63s
#    150K .......... .......... .......... .......... ..........  1% 26.9M 47s
#    200K .......... .......... .......... .......... ..........  2%  257K 47s
#    250K .......... .......... .......... .......... ..........  2% 21.8M 39s
# ...

# %%
# %sh
wget https://ftp.ibge.gov.br/Trabalho_e_Rendimento/Pesquisa_Nacional_por_Amostra_de_Domicilios_PNAD_COVID19/Microdados/Dados/PNAD_COVID_092020.zip
# Out:
# --2023-10-31 20:05:23--  https://ftp.ibge.gov.br/Trabalho_e_Rendimento/Pesquisa_Nacional_por_Amostra_de_Domicilios_PNAD_COVID19/Microdados/Dados/PNAD_COVID_092020.zip
# Resolving ftp.ibge.gov.br (ftp.ibge.gov.br)... 191.235.100.86
# Connecting to ftp.ibge.gov.br (ftp.ibge.gov.br)|191.235.100.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12371845 (12M) [application/zip]
# Saving to: ‘PNAD_COVID_092020.zip’
#
#      0K .......... .......... .......... .......... ..........  0%  128K 94s
#     50K .......... .......... .......... .......... ..........  0% 1.68M 50s
#    100K .......... .......... .......... .......... ..........  1%  257K 49s
#    150K .......... .......... .......... .......... ..........  1%  300K 46s
#    200K .......... .......... .......... .......... ..........  2% 43.5M 37s
#    250K .......... .......... .......... .......... ..........  2%  259K 38s
# ...

# %%
# %sh
unzip PNAD_COVID_082020.zip
# Out:
# Archive:  PNAD_COVID_082020.zip
#   inflating: PNAD_COVID_082020.csv

# %%
# %sh
unzip PNAD_COVID_092020.zip
# Out:
# Archive:  PNAD_COVID_092020.zip
#   inflating: PNAD_COVID_092020.csv

# %%
# %sh
pwd
# Out:
# /databricks/driver

# %%
dbutils.fs.cp('file:/databricks/driver/PNAD_COVID_072020.csv','dbfs:/FileStore/')
# Out:
# Out[13]: True

# %%
dbutils.fs.cp('file:/databricks/driver/PNAD_COVID_082020.csv','dbfs:/FileStore/')
# Out:
# Out[14]: True

# %%
dbutils.fs.cp('file:/databricks/driver/PNAD_COVID_092020.csv','dbfs:/FileStore/')
# Out:
# Out[15]: True
